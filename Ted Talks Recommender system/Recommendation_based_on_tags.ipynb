# %% [markdown]
# # Ted Talks - Recommender System

# %% [markdown]
# ### Meet the data
# The data we will use comes in as a tabular flat file, the transcript for each talk is stored in a row across a column named transcript. Here is how the file looks like

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

df1 = pd.read_csv('ted_main.csv')

# %%
df1.head()
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
# 2       124  New York Times columnist David Pogue takes aim...      1286
# 3       200  In an emotionally charged talk, MacArthur-winn...      1116
# 4       593  You've never seen data presented like this. Wi...      1190
#
#      event   film_date  languages   main_speaker  \
# 0  TED2006  1140825600         60   Ken Robinson
# 1  TED2006  1140825600         43        Al Gore
# 2  TED2006  1140739200         26    David Pogue
# 3  TED2006  1140912000         35  Majora Carter
# 4  TED2006  1140566400         48   Hans Rosling
#
#                                             name  num_speaker  published_date  \
# 0      Ken Robinson: Do schools kill creativity?            1      1151367060
# 1           Al Gore: Averting the climate crisis            1      1151367060
# 2                  David Pogue: Simplicity sells            1      1151367060
# 3             Majora Carter: Greening the ghetto            1      1151367060
# 4  Hans Rosling: The best stats you've ever seen            1      1151440680
#
#                                              ratings  \
# 0  [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# 1  [{'id': 7, 'name': 'Funny', 'count': 544}, {'i...
# 2  [{'id': 7, 'name': 'Funny', 'count': 964}, {'i...
# 3  [{'id': 3, 'name': 'Courageous', 'count': 760}...
# 4  [{'id': 9, 'name': 'Ingenious', 'count': 3202}...
#
#                                        related_talks  \
# 0  [{'id': 865, 'hero': 'https://pe.tedcdn.com/im...
# 1  [{'id': 243, 'hero': 'https://pe.tedcdn.com/im...
# 2  [{'id': 1725, 'hero': 'https://pe.tedcdn.com/i...
# 3  [{'id': 1041, 'hero': 'https://pe.tedcdn.com/i...
# 4  [{'id': 2056, 'hero': 'https://pe.tedcdn.com/i...
#
#                      speaker_occupation  \
# 0                       Author/educator
# 1                      Climate advocate
# 2                  Technology columnist
# 3    Activist for environmental justice
# 4  Global health expert; data visionary
#
#                                                 tags  \
# 0  ['children', 'creativity', 'culture', 'dance',...
# 1  ['alternative energy', 'cars', 'climate change...
# 2  ['computers', 'entertainment', 'interface desi...
# 3  ['MacArthur grant', 'activism', 'business', 'c...
# 4  ['Africa', 'Asia', 'Google', 'demo', 'economic...
#
#                              title  \
# 0      Do schools kill creativity?
# 1      Averting the climate crisis
# 2                 Simplicity sells
# 3              Greening the ghetto
# 4  The best stats you've ever seen
#
#                                                  url     views
# 0  https://www.ted.com/talks/ken_robinson_says_sc...  47227110
# 1  https://www.ted.com/talks/al_gore_on_averting_...   3200520
# 2  https://www.ted.com/talks/david_pogue_says_sim...   1636292
# 3  https://www.ted.com/talks/majora_carter_s_tale...   1697550
# 4  https://www.ted.com/talks/hans_rosling_shows_t...  12005869

# %%
df1_new = df1[['comments', 'event', 'main_speaker','title', 'speaker_occupation', 'views', 'published_date']]

# %% [markdown]
# ### Recommendation system based on Tags

# %% [markdown]
# Clean the **Tags**

# %%
import re

# %%
def clean_tags(x):
    letter_only=re.sub("[^a-zA-Z]", " ", x)
    return ' '.join(letter_only.split()).lower()

# %%
df1_new['tags']=df1['tags']
df1_new.tags=df1_new.tags.astype('str')

# %%
df1_new['tags'] = df1_new['tags'].apply(clean_tags)

# %%
df1_new['tags'].head()
# Out:
# 0    children creativity culture dance education pa...
# 1    alternative energy cars climate change culture...
# 2    computers entertainment interface design media...
# 3    macarthur grant activism business cities envir...
# 4    africa asia google demo economics global devel...
# Name: tags, dtype: object

# %% [markdown]
# ### Convert to sparse matrix using count vectorize

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv=CountVectorizer()
cv_tags=cv.fit_transform(df1_new['tags'])
df_genres=pd.DataFrame(cv_tags.todense(), columns=cv.get_feature_names(), index=df1_new['title'])

# %% [markdown]
# ### Get Similarity Scores using cosine similarity
#
# The cosine similarity will become a means for us to find out how similar the one Ted Talk is to the other.

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
cos = cosine_similarity(cv_tags)

# %% [markdown]
# Let's check how we faired, by examining the recommendations. Let's pickup, any Ted Talk Title from, the list, let's say we pick up:

# %% [markdown]
# #### Recommendation using Title

# %%
def get_recommendation_based_title(x):
    index_to_search = df1_new[df1_new['title']==x].index[0]
    series_similar=pd.Series(cos[index_to_search])
    index_similar=series_similar.sort_values(ascending=False).head(10).index
    return df1_new.loc[index_similar]

# %%
get_recommendation_based_title('Do schools kill creativity?')
# Out:
#       comments                event      main_speaker  \
# 0         4553              TED2006      Ken Robinson
# 1420       818      TEDxMidAtlantic      Colin Powell
# 1498       120  TED Talks Education   Pearl Arredondo
# 280        174            LIFT 2007      Sugata Mitra
# 830        301      TEDxMidAtlantic  Diana Laufenberg
# 654        795              TED2010      Adora Svitak
# 1493       632  TED Talks Education      Rita Pierson
# 1588       313              TED2013       James Flynn
# 1033       252       TEDGlobal 2011     Alison Gopnik
# 1023       155       TEDGlobal 2011      Geoff Mulgan
#
#                                                   title  \
# 0                           Do schools kill creativity?
# 1420                                Kids need structure
# 1498   My story, from gangland daughter to star teacher
# 280                           Kids can teach themselves
# 830                         How to learn? From mistakes
# 654                     What adults can learn from kids
# 1493                         Every kid needs a champion
# 1588  Why our IQ levels are higher than our grandpar...
# 1033                              What do babies think?
# 1023                 A short intro to the Studio School
#
#                   speaker_occupation     views  published_date  \
# 0                    Author/educator  47227110      1151367060
# 1420  Former U.S. Secretary of State   1485801      1358957905
# 1498                         Teacher   1059278      1368025500
# 280             Education researcher   1486853      1219798800
# 830                         Educator   1882742      1292431320
# 654                    Child prodigy   4782854      1270142220
# 1493                        Educator   7469445      1367589737
# 1588               Moral philosopher   2991225      1380208246
# 1033  Child development psychologist   2901853      1318259576
# 1023              Social commentator    667985      1317136687
#
#                                                    tags
# 0     children creativity culture dance education pa...
# 1420  tedx children culture education parenting stud...
# 1498                        children education teaching
# 280   children cities culture education global issue...
# 830                     tedx children culture education
# 654          children creativity education intelligence
# 1493             children education motivation teaching
# 1588                                  culture education
# 1033        brain children culture education psychology
# 1023           creativity culture design education work

# %% [markdown]
# #### Recommendation using Speakers

# %%
def get_recommendation_based_speakers(x):
    index_to_search = df1_new[df1_new['main_speaker']==x].index[0]
    series_similar=pd.Series(cos[index_to_search])
    index_similar=series_similar.sort_values(ascending=False).head(10).index
    return df1_new.loc[index_similar]

# %%
get_recommendation_based_speakers('Hans Rosling')
# Out:
#       comments                 event          main_speaker  \
# 4          593               TED2006          Hans Rosling
# 117        261               TED2007          Hans Rosling
# 502        122             TED@State          Hans Rosling
# 1818       177  TEDSalon Berlin 2014  Hans and Ola Rosling
# 122        136               TED2007           Emily Oster
# 127         97        TEDGlobal 2007        George Ayittey
# 1861       100        TEDGlobal 2014         Michael Green
# 1094       119          TEDxCanberra          Thomas Pogge
# 1607       207        TEDGlobal 2013     Charles Robertson
# 234        139               TED2008          Paul Collier
#
#                                                   title  \
# 4                       The best stats you've ever seen
# 117                             New insights on poverty
# 502                  Let my dataset change your mindset
# 1818             How not to be ignorant about the world
# 122                Flip your thinking on AIDS in Africa
# 127                     Africa's cheetahs versus hippos
# 1861  What the Social Progress Index can reveal abou...
# 1094                        Medicine for the 99 percent
# 1607                                 Africa's next boom
# 234                                The "bottom billion"
#
#                         speaker_occupation     views  published_date  \
# 4     Global health expert; data visionary  12005869      1151440680
# 117   Global health expert; data visionary   3243784      1182762720
# 502   Global health expert; data visionary   1471039      1251334800
# 1818  Global health expert; data visionary   3673455      1410449403
# 122           Assumption-busting economist    854967      1184221140
# 127                              Economist    648234      1185791520
# 1861                Social progress expert   1132771      1415721331
# 1094                           Philosopher    242251      1324220484
# 1607            Emerging-markets economist   1204089      1382454693
# 234                              Economist    990220      1211986800
#
#                                                    tags
# 4     africa asia google demo economics global devel...
# 117   africa asia google economics global developmen...
# 502   africa asia data global development global iss...
# 1818                    global issues health statistics
# 122   aids africa economics global issues health sci...
# 127   africa business corruption economics entrepren...
# 1861          economics global issues policy statistics
# 1094                tedx economics global issues health
# 1607            africa business economics global issues
# 234   africa activism business economics global deve...

# %% [markdown]
# #### Recommendation using Speaker Ocuupation

# %%
def get_recommendation_based_speaker_occupation(x):
    index_to_search = df1_new[df1_new['speaker_occupation']==x].index[0]
    series_similar = pd.Series(cos[index_to_search])
    index_similar = series_similar.sort_values(ascending = False).head(10).index
    return df1_new.loc[index_similar]

# %%
get_recommendation_based_speaker_occupation('Artist')
# Out:
#       comments           event        main_speaker  \
# 78          84         TED2003           Vik Muniz
# 959        281         TED2011        Shea Hembrey
# 495        103  TEDGlobal 2009       Willard Wigan
# 1152       181  INK Conference  Shilo Shiv Suleman
# 1312       223  TEDGlobal 2012      Kirby Ferguson
# 382         21         TED1998       Milton Glaser
# 801        144  TEDGlobal 2010       Miwa Matreyek
# 351         58         TED2001          Eva Zeisel
# 1574       257  TEDGlobal 2013         Alexa Meade
# 1190        98         TED2012       Marco Tempest
#
#                                               title     speaker_occupation  \
# 78       Art with wire, sugar, chocolate and string                 Artist
# 959                        How I became 100 artists     Artist and curator
# 495            Hold your breath for micro-sculpture         Micro-sculptor
# 1152                  Using tech to enable dreaming                 Artist
# 1312                              Embrace the remix  Filmmaker and Remixer
# 382                  Using design to make ideas new       Graphic designer
# 801   Glorious visions in animation and performance      Multimedia artist
# 351                   The playful search for beauty               Designer
# 1574                         Your body is my canvas          Visual artist
# 1190        A magical tale (with augmented reality)     Techno-illusionist
#
#         views  published_date  \
# 78    1149090      1175731860
# 959   1486880      1308061740
# 495    640722      1249261200
# 1152   576918      1329929988
# 1312  1356163      1344610939
# 382    382985      1234314000
# 801    829399      1288349340
# 351    438972      1228803420
# 1574  2682427      1378480353
# 1190  1394503      1333119630
#
#                                                    tags
# 78      brazil animation art creativity design illusion
# 959                  art creativity design storytelling
# 495                                      art creativity
# 1152                                     art creativity
# 1312                                     art creativity
# 382         art communication creativity culture design
# 801         animation art design performance technology
# 351              art creativity design exploration play
# 1574         art creativity design painting photography
# 1190  art design entertainment illusion magic techno...

# %% [markdown]
# To get the similarity tags we are using count vectorizer to make the binary, and then transform it into numbers that can be count based on their cosine similarity to get their nearest tags.
